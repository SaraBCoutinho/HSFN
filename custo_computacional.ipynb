# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import pandas as pd

dataframe=pd.DataFrame(columns=['Grupo','LR','RF','NB','Média'])
dataframe.loc[0]=['A',1.539,38.166,0.303,13.336]
dataframe.loc[1]=['B',1.449,23.257,0.06,8.255]
dataframe.loc[2]=['C',0.298,2.306,0.009,0.871]
dataframe.loc[3]=['D (acurácia)',190.216,690.215,3.343,294.591]
dataframe.loc[4]=['D (precisão)',90.278,711.519,2.871,268.222]
dataframe.loc[5]=['D (revocação)',97.406,708.95,2.917,269.757]
dataframe.loc[6]=['D (medida f1)',100.046,705.232,2.957,269.411]
dataframe = dataframe.drop(columns=['Média'])
dataframe = dataframe.set_index(['Grupo'])
Index = dataframe.index
Cols = dataframe.columns

sns.heatmap(dataframe,linewidths=1.4, linecolor=	'#1C1C1C',cmap=plt.cm.gray_r, annot=True,fmt=".2f")
plt.xlabel('Tempo por Meta-classificador (segundos)')
plt.savefig('custo_heatmap.pdf')
